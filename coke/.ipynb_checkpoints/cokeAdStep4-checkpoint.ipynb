# %%
import numpy as np
import cv2 
import os
from matplotlib import pyplot as plt
import time

# %%
# %pwd
# Out:
# 'C:\\Users\\rithanya\\Documents\\Python\\Industrial_Safety\\coke'

# %%
#os.chdir('C:/Users/keerthana.c/Desktop/LOYOLA/') 
img = cv2.imread('cokead/negimg/1.jpg')

# %%
from matplotlib import pyplot as plt
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
for imgfolder in os.listdir('cokead/'): #iterate thru each of the 5 celeb folders
    for filename in os.listdir('cokead/' + imgfolder):# iterate thru each image in a celeb folder
        filename = 'cokead/' + imgfolder + '/' + filename # build the path to the image file
        print(filename) # print the filename read. For debugging purpose only
        img = cv2.imread(filename,0) # read the image using OpenCV
        plt.imshow(img, cmap = 'gray', interpolation = 'bicubic') # display all images read
        plt.xticks([]), plt.yticks([])
        plt.show()
# Out:
# cokead/negimg/1.jpg
# cokead/negimg/10.jpg
# cokead/negimg/11.jpg
# cokead/negimg/12.jpg
# cokead/negimg/2.jpg
# cokead/negimg/3.jpg
# cokead/negimg/4.jpg
# cokead/negimg/5.jpg
# cokead/negimg/6.jpg
# cokead/negimg/7.jpg
# cokead/negimg/8.jpg
# cokead/negimg/9.jpg

# %%
for imgfolder in os.listdir('cokead/'):
    for filename in os.listdir('cokead/' + imgfolder):
        filename = 'cokead/' + imgfolder + '/' + filename
        img = cv2.imread(filename,0)
        print(img.shape)
# Out:
# (168, 301)
# (193, 261)
# (168, 299)
# (168, 300)
# (202, 250)
# (168, 300)
# (167, 302)
# (194, 259)
# (256, 197)
# (159, 318)
# (168, 300)
# (137, 367)

# %%
for imgfolder in os.listdir('cokead/'):
    for filename in os.listdir('cokead/' + imgfolder):
        filename = 'cokead/' + imgfolder + '/' + filename        #print(filename)
        img = cv2.imread(filename,0)
        img = cv2.resize(img, (225,225), interpolation = cv2.INTER_AREA)
        #print(type(img))
        print(img.shape)
# Out:
# (225, 225)
# (225, 225)
# (225, 225)
# (225, 225)
# (225, 225)
# (225, 225)
# (225, 225)
# (225, 225)
# (225, 225)
# (225, 225)
# (225, 225)
# (225, 225)

# %%
# haarcascades_path = os.listdir('C:/Users/keerthana.c/Miniconda3/Library/etc/haarcascades/')
# frontface_alt_cascade = 'C:/Users/keerthana.c/Miniconda3/Library/etc/haarcascades/haarcascade_frontalface_alt.xml'
# frontface_default_cascade = 'C:/Users/keerthana.c/Miniconda3/Library/etc/haarcascades/haarcascade_frontalface_default.xml'
# frontface_alt2_cascade = 'C:/Users/keerthana.c/Miniconda3/Library/etc/haarcascades/haarcascade_frontalface_alt2.xml'
# frontface_alt_tree_cascade = 'C:/Users/keerthana.c/Miniconda3/Library/etc/haarcascades/haarcascade_frontalface_alt2.xml'

# cokelogo_cascade = "C:/Users/rithanya/Documents/Python/Industrial_Safety/coke/cascade/cokelogo50.xml"
haarcascade_fullbody = "C:/Users/rithanya/Miniconda3/Library/etc/haarcascades/haarcascade_fullbody.xml"
#cokelogo_cascade = "C:/Users/rithanya/Documents/Python/Industrial_Safety/coke/cascade2/cokelogo20fromneg.xml"

# %%
# faceCascade_default = cv2.CascadeClassifier(frontface_default_cascade)
# faceCascade_alt = cv2.CascadeClassifier(frontface_alt_cascade)
# faceCascade_alt2 = cv2.CascadeClassifier(frontface_alt2_cascade)
# faceCascade_alt_tree = cv2.CascadeClassifier(frontface_alt_tree_cascade)

#cokecascade = cv2.CascadeClassifier(cokelogo_cascade)
fullbodycascade = cv2.CascadeClassifier(haarcascade_fullbody)

# %%
#utility function to apply different cascade function on the images at difference scaleFactor
def detect(faceCascade, gray_,  scaleFactor_ = 1.1):
    faces = faceCascade.detectMultiScale(gray_,
                    scaleFactor= scaleFactor_,
                    minNeighbors=5,
                    minSize=(30, 30),
                    flags = cv2.CASCADE_SCALE_IMAGE
                )
    return faces

# %%
import time
i = 0
t1 = time.time()
for imgfolder in os.listdir('cokead/'): #iterate thru each of the 5 celeb folders
    if(imgfolder != '.DS_Store'):
        for filename in os.listdir('cokead/' + imgfolder):# iterate thru each image in a celeb folder
            filename = 'cokead/' + imgfolder + '/' + filename # build the path to the image file
            if(filename.endswith('.jpg')):
                #print(filename) # print the filename read. For debugging purpose only
                img = cv2.imread(filename) # read the image using OpenCV
                gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                cokelogos = detect(fullbodycascade, gray, 1.1)
#                 if (len(faces)!=1):
#                     faces = detect(faceCascade_default, gray, 1.2)
#                     if(len(faces) != 1):
#                         faces = detect(faceCascade_alt2,gray, 1.1)
#                         if(len(faces) != 1):
#                             faces = detect(faceCascade_alt2,gray, 1.2)
#                             if(len(faces) != 1):
#                                 faces = detect(faceCascade_alt, gray, 1.1)
#                                 if(len(faces) != 1):
#                                     faces = detect(faceCascade_alt, gray, 1.2)
#                                     if(len(faces) != 1):
#                                         faces = detect(faceCascade_alt_tree, gray, 1.1)
#                                         if(len(faces) != 1):
#                                             faces = detect(faceCascade_alt_tree, gray, 1.2)
#                                             if(len(faces) != 1):
#                                                 i = i + 1
#                                                 #continue
                for (x, y, w, h) in cokelogos:
                    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
                plt.imshow(img, cmap = 'gray', interpolation = 'bicubic') # display all images read
                print(filename) # print the filename read. For debugging purpose only
                plt.xticks([]), plt.yticks([])
                plt.show()
                                                

t2 = time.time()
print ('Time taken %f seconds' %  round((t2 - t1),2))
print(i)
# Out:
# cokead/negimg/1.jpg
# cokead/negimg/10.jpg
# cokead/negimg/11.jpg
# cokead/negimg/12.jpg
# cokead/negimg/13.jpg
# cokead/negimg/14.jpg
# cokead/negimg/2.jpg
# cokead/negimg/3.jpg
# cokead/negimg/4.jpg
# cokead/negimg/5.jpg
# cokead/negimg/6.jpg
# cokead/negimg/7.jpg
# cokead/negimg/8.jpg
# cokead/negimg/9.jpg
# Time taken 2.470000 seconds
# 0

# %%
from sklearn.feature_extraction.image import PatchExtractor

def extract_patches(img, N, scale=1.0, patch_size=(100,100)):
    extracted_patch_size = tuple((scale * np.array(patch_size)).astype(int))
    extractor = PatchExtractor(patch_size=extracted_patch_size,
                               max_patches=N, random_state=0)
    patches = extractor.transform(img[np.newaxis])
    if scale != 1:
        patches = np.array([transform.resize(patch, patch_size)
                            for patch in patches])
    return patches

# %%
pwd
# Out:
# 'C:\\Users\\rithanya\\Documents\\Python\\Industrial_Safety\\coke'

# %%
images = []
rootfolder = 'NegFromAds'
for imgfolder in os.listdir(rootfolder): #iterate thru each of the 5 celeb folders
    if(imgfolder != '.DS_Store'):
        for filename in os.listdir(rootfolder + '/' + imgfolder):# iterate thru each image in a celeb folder
            filename = rootfolder + '/' + imgfolder + '/' + filename # build the path to the image file
            if(filename.endswith('.jpg')):
                print(filename)
                img = cv2.imread(filename)
                if(img):
                    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                    images.append(img)
#negative_patches = np.vstack([extract_patches(im, 1000, scale)
#                              for im in images for scale in [0.5, 1.0, 2.0]])
#negative_patches.shape

len(images)
# Out:
# NegFromAds/7up advertisements/1. cecce11ea4526c76a5a8b68a02165497.jpg
# (906, 700, 3)
# NegFromAds/7up advertisements/10. 1950s.jpg
# (451, 355, 3)
# NegFromAds/7up advertisements/100. l-1jj20ire33azx0.jpg
# (851, 660, 3)
# NegFromAds/7up advertisements/11. 225289098.jpg
# (408, 544, 3)
# NegFromAds/7up advertisements/12. sevenup076.jpg
# (400, 321, 3)
# NegFromAds/7up advertisements/13. vertical-poster.jpg
# (842, 595, 3)
# NegFromAds/7up advertisements/14. d4ffbce2a2555822b16378da3635cd55--brand-advertising-advertising-signs.jpg
# (964, 736, 3)
# NegFromAds/7up advertisements/15. 7upsnowflake.jpg
# (408, 544, 3)
# NegFromAds/7up advertisements/16. beverages-7-up-48-swscan00294.jpg
# (600, 470, 3)
# NegFromAds/7up advertisements/17. 7-up-humming-bird-small-98676.jpg
# (450, 600, 3)
# NegFromAds/7up advertisements/18. f690885d218b0a1b3ed365a0836cc765.jpg
# (539, 400, 3)
# NegFromAds/7up advertisements/19. 4e9df06e84184aa3d6bbfd71a86d6379.jpg
# (880, 660, 3)
# NegFromAds/7up advertisements/2. nothing-does-it-like-7up.jpg
# (661, 500, 3)
# NegFromAds/7up advertisements/20. sevenupmandrinks.jpg
# (331, 536, 3)
# NegFromAds/7up advertisements/21. 5b2d2ffc65f7b624e3990fcf337a796f--retro-ads-vintage-advertisements.jpg
# (640, 455, 3)
# NegFromAds/7up advertisements/22. vintage-ad-coca-cola-and-7-up-ads.jpg
# (467, 720, 3)
# NegFromAds/7up advertisements/23. 7up3.jpg
# (440, 840, 3)
# NegFromAds/7up advertisements/24. 120c85d3633c6e104fa32ff2274eb6a7.jpg
# (654, 496, 3)
# NegFromAds/7up advertisements/25. 7up_baseball.jpg
# (688, 541, 3)
# NegFromAds/7up advertisements/26. 7_up-babies.jpg
# (355, 650, 3)
# NegFromAds/7up advertisements/27. 7up_new_logo_01.jpg
# (318, 450, 3)
# NegFromAds/7up advertisements/28. brf09j8bwrfggy.jpg
# (577, 420, 3)
# NegFromAds/7up advertisements/29. c3037c6d8e288248c2951082d77d430d.jpg
# (570, 420, 3)
# NegFromAds/7up advertisements/3. 759567309869.jpg
# (427, 640, 3)
# NegFromAds/7up advertisements/30. 7up1963.jpg
# (575, 420, 3)
# NegFromAds/7up advertisements/31. 660408ff2b8ed93d7e50e32297dcabd4--vintage-soft-vintage-ladies.jpg
# (586, 420, 3)
# NegFromAds/7up advertisements/32. 189704102_2a48788ab0_o.jpg
# (700, 534, 3)
# NegFromAds/7up advertisements/34. a9591479c63b914705d36b432fdbad53--vintage-posters-vintage-ads.jpg
# (480, 640, 3)
# NegFromAds/7up advertisements/35. 2755a.jpg
# (412, 300, 3)
# NegFromAds/7up advertisements/36. fresh-up-with-7-up-ad-nov-1946-1.jpg
# (504, 620, 3)
# NegFromAds/7up advertisements/37. 730.jpg
# (640, 640, 3)
# NegFromAds/7up advertisements/39. 7up_limon_by_comandos2008.jpg
# (849, 600, 3)
# NegFromAds/7up advertisements/4. 1809cfa09f28461a21d3301b5fb00ff7.jpg
# (856, 625, 3)
# NegFromAds/7up advertisements/40. 7up.jpg
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-d26d2b211c3e> in <module>()
#       8                 print(filename)
#       9                 img = cv2.imread(filename)
# ---> 10                 print(img.shape)
#      11                 img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#      12                 images.append(img)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
fig, ax = plt.subplots(6, 10)
for i, axi in enumerate(ax.flat):
    axi.imshow(negative_patches[500 * i], cmap='gray')
    axi.axis('off')
